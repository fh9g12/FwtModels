# %% [markdown]
# ## Benchmarking
#
#
# I'm using this code to benchmark underlying function and my code generation tactics
#
# will use a 2B1T + FWTD model and relise it at 20 m/s & 5 deg aoa

# %%
import sympy as sym
import sympy.physics.mechanics as me
from sympy.abc import t as time
import pandas as pd
import seaborn as sns

import numpy as np
from scipy.integrate import odeint,LSODA,BDF,solve_ivp
from scipy.linalg import eig
from scipy.optimize import fsolve
import matplotlib.pyplot as plt

import sys, os

sys.path.insert(1, os.path.join(sys.path[0], '../..'))
import custom_plot_objects as cpo

import ModelFramework as mf
import ModelFramework.Elements as ele
import ModelFramework.ExternalForces as ef

me.mechanics_printing()

# %% [markdown]
# ### Define the Model
#
# #### Create Parameter instance

# %%
b_modes = 3
t_modes = 3
fwt_modes = 0
# lets go for B2T2 (so 5 DoF)
p = mf.ModelParameters.DynamicModel(b_modes + t_modes + fwt_modes)

## Create some global parameters
p.c = mf.ModelSymbol(value = 1.8,string = 'c') # chord of wing
p.s_t = mf.ModelSymbol(value = 12,string = 's_t') # total semi-span of wing
p.rho_t = mf.ModelSymbol(value = 19.53,string = 'rho_t') # per per unit area (kg/m^2)
p.ratio_fwt = mf.ModelSymbol(value = 0.2,string = 'sigma') # percentage of wing that is a FWT


# Respective spans
p.s_0 =  p.s_t*(1-p.ratio_fwt) # span of inner wing
p.s_1 =  p.s_t*p.ratio_fwt # span of inner wing

# Inner Wing stiffness Properties
p.EI = mf.ModelSymbol(value = 9.77e6,string = 'EI') # Bending stiffness for the wing
p.GJ = mf.ModelSymbol(value = 0.99e6,string = 'GJ') # Torsional Stiffness for the wing

# Location of flexural axes
p.e_0 = mf.ModelSymbol(value = 0.08,string = 'e_0')
p.x_f0 = sym.Rational(1,4)*p.c + p.e_0*p.c
p.e_1 = mf.ModelSymbol(value = 0.08,string = 'e_1') # e for the FWT
p.x_f1 = sym.Rational(1,4)*p.c + p.e_1*p.c

# FWT Properties
p.m_1 =  mf.ModelSymbol(value = p.rho_t.value*p.c.value*p.s_t.value*p.ratio_fwt.value,string = 'm_1') # FWT mass
p.I_xx_1 = sym.Rational(1,12)*p.m_1*p.s_1**2 # inertia of FWT (uniform bar)
p.Lambda = mf.ModelSymbol(value = np.deg2rad(10),string = 'Lambda') # Flare Angle
p.Delta_m = mf.ModelSymbol(value = 0,string = 'Delta_m') # additional mass to apply at the FWT CoM

# Symbols to translate along inner wing and FWT
p.y_0 = sym.Symbol('y_0') # inner wing y chord
p.x_0 = sym.Symbol('x_0') # inner wing x chord
p.y_1 = sym.Symbol('y_1') # FWT y chord
p.x_1 = sym.Symbol('x_1') # FWT x chord

## Aero Parameters
p.rho = mf.ModelSymbol(value = 1.225,string = 'rho')                 # density
p.V = mf.ModelSymbol(value = 10,string = 'V')                        # velocity
p.g  = mf.ModelSymbol(value = 9.81,string = 'g')                     # gravity
p.alpha_r = mf.ModelSymbol(value = np.deg2rad(3),string = 'alpha_r') # root AoA
p.M_thetadot = mf.ModelSymbol(value = -1.2,string = 'M_thetadot')    # Unsteady Torsional Term 

## Main Wing Specific
p.a_0 = mf.ModelSymbol(value = 2*np.pi,string = 'a_0')               # C_L slope of main wing

## FWT Specific
p.a_1 = p.a_0 - p.a_0/p.s_1*p.y_1                                    # C_L slope of FWT
p.alpha_1 = mf.ModelSymbol(value = 0,string = 'alpha_1')             # FWT alpha
p.alphadot_1 = mf.ModelSymbol(value = 0,string = 'alphadot_1')       # FWT alphadot

## Numeric Model Constants
p.fp = mf.ModelMatrix(value =[0]*p.qs*2,symbols=sym.symbols(f'qtilde:{p.qs*2}')) # The stationary point

# Factor to change the size of joint values
p.eta = mf.ModelMatrix(value = [1]*(b_modes+t_modes+fwt_modes),symbols=sym.symbols(f'eta:{p.qs}'))

# %%
# %%time
#get shape functions for main wing
z_0,tau_0 = mf.ShapeFunctions_BN_TM(b_modes,t_modes,p.q[:],p.y_0,p.x_0,p.x_f0,0,factor=p.eta)

tau_1 = tau_0.subs(p.y_0,p.s_0)
z_crit_1 = z_0.subs({p.y_0:p.s_0,p.x_0:p.x_f0})
dz_dy_crit = z_0.subs(p.x_0,p.x_f0).diff(p.y_0).subs(p.y_0,p.s_0)
z_1 = z_crit_1+dz_dy_crit*p.y_1 - tau_1*(p.x_1-p.x_f1)
z_1
# Out:
# CPU times: user 1.07 ms, sys: 2 µs, total: 1.08 ms
# Wall time: 1.08 ms
#   4        4        3        3        2        2         ⎛    3        3
# sₜ ⋅(1 - σ) ⋅q₂   sₜ ⋅(1 - σ) ⋅q₁   sₜ ⋅(1 - σ) ⋅q₀      ⎜4⋅sₜ ⋅(1 - σ) ⋅q₂
# ─────────────── + ─────────────── + ─────────────── + y₁⋅⎜───────────────── +
#        η₂                η₁                η₀            ⎝        η₂
#
#     2        2                     ⎞                    ⎛  3        3        2
# 3⋅sₜ ⋅(1 - σ) ⋅q₁   2⋅sₜ⋅(1 - σ)⋅q₀⎟   ⎛        c     ⎞ ⎜sₜ ⋅(1 - σ) ⋅q₅   sₜ
# ───────────────── + ───────────────⎟ - ⎜-c⋅e₁ - ─ + x₁⎟⋅⎜─────────────── + ───
#         η₁                 η₀      ⎠   ⎝        4     ⎠ ⎝       η₅
#
#         2                   ⎞
# ⋅(1 - σ) ⋅q₄   sₜ⋅(1 - σ)⋅q₃⎟
# ──────────── + ─────────────⎟
#     η₄               η₃     ⎠

# %%
# %%time
#define wrefernce frames
wing_root_frame = mf.HomogenousTransform().R_y(p.alpha_r)
wing_frame = wing_root_frame.Translate(p.x_0,p.y_0,z_0)
wing_flexural_frame = wing_frame.subs({p.x_0:p.x_f0})

root_flexural_frame = wing_flexural_frame.subs({p.y_0:p.s_0}).Translate(0,p.y_1,z_1.subs(p.x_1,p.x_f1))

#Create Elemnts
M_wing = ele.MassMatrix(p.rho_t)
M_fwt = ele.MassMatrix(p.m_1,I_xx = p.I_xx_1)

inner_wing_ele = ele.FlexiElement(wing_root_frame,M_wing,p.x_0,p.y_0,z_0,p.c,p.s_0,p.x_f0,p.EI,p.GJ,gravityPot=False)
tip_wing_ele = ele.FlexiElement(wing_root_frame,M_wing,p.x_1,p.s_0+p.y_1,z_1,p.c,p.s_1,p.x_f1,p.EI,p.GJ,gravityPot=False)
# Out:
# CPU times: user 10.9 ms, sys: 405 µs, total: 11.3 ms
# Wall time: 10.9 ms

# %%
# Create AeroForces
wing_AeroForces = ef.AeroForce.Generate(p,wing_flexural_frame,p.a_0,(p.y_0,0,p.s_0),
                               alphadot = tau_0 if isinstance(tau_0,int) else tau_0.diff(me.dynamicsymbols._t),
                               M_thetadot = p.M_thetadot,
                               e = p.e_0,
                               rootAlpha = p.alpha_r,
                               deltaAlpha = tau_0,
                               alpha_zero = 0)

# %% [markdown]
# #### Create Transforms

# %%
tip_AeroForces = ef.AeroForce.Generate(p,root_flexural_frame,p.a_1,(p.y_1,0,p.s_1),
                               alphadot = tau_1.diff(me.dynamicsymbols._t),
                               M_thetadot = p.M_thetadot,
                               e = p.e_1,
                               rootAlpha = p.alpha_r,
                               deltaAlpha = tau_1,
                               alpha_zero = 0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-105-05234b966dab> in <module>
#       5                                rootAlpha = p.alpha_r,
#       6                                deltaAlpha = tau_1,
# ----> 7                                alpha_zero = 0)
#
# ~/Documents/GitHub/FwtModels/Workbooks/5_Non-linear FWTD Assumed Shapes/../../ModelFramework/ExternalForces/AeroForce.py in Generate(cls, FwtParams, Transform, C_L, int_tuple, alphadot, M_thetadot, e, rootAlpha, deltaAlpha, alpha_zero)
#      40         dQ_M = (velocity_frame.ManipJacobian(p.q)).T
#      41         dQ_M *= velocity_frame.InvAdjoint().T
# ---> 42         dQ_M = cls._trigsimp(dQ_M)
#      43         dQ_M *= wrench_moment
#      44
#
# ~/Documents/GitHub/FwtModels/Workbooks/5_Non-linear FWTD Assumed Shapes/../../ModelFramework/ExternalForces/AeroForce.py in _trigsimp(expr)
#      56     @staticmethod
#      57     def _trigsimp(expr):
# ---> 58         return sym.trigsimp(sym.powsimp(sym.cancel(sym.expand(expr))))
#      59
#      60     def linearise(self,p):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/trigsimp.py in trigsimp(expr, **opts)
#     474     _eval_trigsimp = getattr(expr, '_eval_trigsimp', None)
#     475     if _eval_trigsimp is not None:
# --> 476         return _eval_trigsimp(**opts)
#     477
#     478     old = opts.pop('old', False)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/matrices/common.py in _eval_trigsimp(self, **opts)
#    2062     def _eval_trigsimp(self, **opts):
#    2063         from sympy.simplify import trigsimp
# -> 2064         return self.applyfunc(lambda x: trigsimp(x, **opts))
#    2065
#    2066
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/matrices/common.py in applyfunc(self, f)
#    1723             raise TypeError("`f` must be callable.")
#    1724
# -> 1725         return self._eval_applyfunc(f)
#    1726
#    1727     def as_real_imag(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/matrices/common.py in _eval_applyfunc(self, f)
#    1663
#    1664     def _eval_applyfunc(self, f):
# -> 1665         out = self._new(self.rows, self.cols, [f(x) for x in self])
#    1666         return out
#    1667
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/matrices/common.py in <listcomp>(.0)
#    1663
#    1664     def _eval_applyfunc(self, f):
# -> 1665         out = self._new(self.rows, self.cols, [f(x) for x in self])
#    1666         return out
#    1667
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/matrices/common.py in <lambda>(x)
#    2062     def _eval_trigsimp(self, **opts):
#    2063         from sympy.simplify import trigsimp
# -> 2064         return self.applyfunc(lambda x: trigsimp(x, **opts))
#    2065
#    2066
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/trigsimp.py in trigsimp(expr, **opts)
#     506                    }[method]
#     507
# --> 508     return trigsimpfunc(expr)
#     509
#     510
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/trigsimp.py in <lambda>(x)
#     499     trigsimpfunc = {
#     500         'fu': (lambda x: fu(x, **opts)),
# --> 501         'matching': (lambda x: futrig(x)),
#     502         'groebner': (lambda x: groebnersimp(x, **opts)),
#     503         'combined': (lambda x: futrig(groebnersimp(x,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/trigsimp.py in futrig(e, **kwargs)
#    1099
#    1100     old = e
# -> 1101     e = bottom_up(e, lambda x: _futrig(x, **kwargs))
#    1102
#    1103     if kwargs.pop('hyper', True) and e.has(HyperbolicFunction):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in <listcomp>(.0)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in <listcomp>(.0)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in <listcomp>(.0)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
# -> 1150             rv = F(rv)
#    1151         elif atoms:
#    1152             rv = F(rv)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/trigsimp.py in <lambda>(x)
#    1099
#    1100     old = e
# -> 1101     e = bottom_up(e, lambda x: _futrig(x, **kwargs))
#    1102
#    1103     if kwargs.pop('hyper', True) and e.has(HyperbolicFunction):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/trigsimp.py in _futrig(e, **kwargs)
#    1167             factor_terms, TR12(x), trigs)],  # expand tan of sum
#    1168         )]
# -> 1169     e = greedy(tree, objective=Lops)(e)
#    1170     return coeff*e
#    1171
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/strategies/core.py in minrule(expr)
#     113     objective = kwargs.get('objective', identity)
#     114     def minrule(expr):
# --> 115         return min([rule(expr) for rule in rules], key=objective)
#     116     return minrule
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/strategies/core.py in <listcomp>(.0)
#     113     objective = kwargs.get('objective', identity)
#     114     def minrule(expr):
# --> 115         return min([rule(expr) for rule in rules], key=objective)
#     116     return minrule
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/strategies/core.py in chain_rl(expr)
#      42     def chain_rl(expr):
#      43         for rule in rules:
# ---> 44             expr = rule(expr)
#      45         return expr
#      46     return chain_rl
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/strategies/core.py in minrule(expr)
#     113     objective = kwargs.get('objective', identity)
#     114     def minrule(expr):
# --> 115         return min([rule(expr) for rule in rules], key=objective)
#     116     return minrule
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/strategies/core.py in <listcomp>(.0)
#     113     objective = kwargs.get('objective', identity)
#     114     def minrule(expr):
# --> 115         return min([rule(expr) for rule in rules], key=objective)
#     116     return minrule
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/fu.py in TR8(rv, first)
#     665         return TR8(expand_mul(Mul(*args)))
#     666
# --> 667     return bottom_up(rv, f)
#     668
#     669
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in <listcomp>(.0)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
# -> 1150             rv = F(rv)
#    1151         elif atoms:
#    1152             rv = F(rv)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/fu.py in f(rv)
#     620         if first:
#     621             n, d = [expand_mul(i) for i in rv.as_numer_denom()]
# --> 622             newn = TR8(n, first=False)
#     623             newd = TR8(d, first=False)
#     624             if newn != n or newd != d:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/fu.py in TR8(rv, first)
#     665         return TR8(expand_mul(Mul(*args)))
#     666
# --> 667     return bottom_up(rv, f)
#     668
#     669
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
# -> 1150             rv = F(rv)
#    1151         elif atoms:
#    1152             rv = F(rv)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/fu.py in f(rv)
#     663         if s:
#     664             args.append(sin(s.pop()))
# --> 665         return TR8(expand_mul(Mul(*args)))
#     666
#     667     return bottom_up(rv, f)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/fu.py in TR8(rv, first)
#     665         return TR8(expand_mul(Mul(*args)))
#     666
# --> 667     return bottom_up(rv, f)
#     668
#     669
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in <listcomp>(.0)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
# -> 1150             rv = F(rv)
#    1151         elif atoms:
#    1152             rv = F(rv)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/fu.py in f(rv)
#     620         if first:
#     621             n, d = [expand_mul(i) for i in rv.as_numer_denom()]
# --> 622             newn = TR8(n, first=False)
#     623             newd = TR8(d, first=False)
#     624             if newn != n or newd != d:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/fu.py in TR8(rv, first)
#     665         return TR8(expand_mul(Mul(*args)))
#     666
# --> 667     return bottom_up(rv, f)
#     668
#     669
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
# -> 1150             rv = F(rv)
#    1151         elif atoms:
#    1152             rv = F(rv)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/fu.py in f(rv)
#     663         if s:
#     664             args.append(sin(s.pop()))
# --> 665         return TR8(expand_mul(Mul(*args)))
#     666
#     667     return bottom_up(rv, f)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/fu.py in TR8(rv, first)
#     665         return TR8(expand_mul(Mul(*args)))
#     666
# --> 667     return bottom_up(rv, f)
#     668
#     669
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in <listcomp>(.0)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
# -> 1150             rv = F(rv)
#    1151         elif atoms:
#    1152             rv = F(rv)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/fu.py in f(rv)
#     620         if first:
#     621             n, d = [expand_mul(i) for i in rv.as_numer_denom()]
# --> 622             newn = TR8(n, first=False)
#     623             newd = TR8(d, first=False)
#     624             if newn != n or newd != d:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/fu.py in TR8(rv, first)
#     665         return TR8(expand_mul(Mul(*args)))
#     666
# --> 667     return bottom_up(rv, f)
#     668
#     669
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
# -> 1150             rv = F(rv)
#    1151         elif atoms:
#    1152             rv = F(rv)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/fu.py in f(rv)
#     663         if s:
#     664             args.append(sin(s.pop()))
# --> 665         return TR8(expand_mul(Mul(*args)))
#     666
#     667     return bottom_up(rv, f)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/fu.py in TR8(rv, first)
#     665         return TR8(expand_mul(Mul(*args)))
#     666
# --> 667     return bottom_up(rv, f)
#     668
#     669
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in <listcomp>(.0)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
# -> 1150             rv = F(rv)
#    1151         elif atoms:
#    1152             rv = F(rv)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/fu.py in f(rv)
#     620         if first:
#     621             n, d = [expand_mul(i) for i in rv.as_numer_denom()]
# --> 622             newn = TR8(n, first=False)
#     623             newd = TR8(d, first=False)
#     624             if newn != n or newd != d:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/fu.py in TR8(rv, first)
#     665         return TR8(expand_mul(Mul(*args)))
#     666
# --> 667     return bottom_up(rv, f)
#     668
#     669
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
# -> 1150             rv = F(rv)
#    1151         elif atoms:
#    1152             rv = F(rv)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/fu.py in f(rv)
#     663         if s:
#     664             args.append(sin(s.pop()))
# --> 665         return TR8(expand_mul(Mul(*args)))
#     666
#     667     return bottom_up(rv, f)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/fu.py in TR8(rv, first)
#     665         return TR8(expand_mul(Mul(*args)))
#     666
# --> 667     return bottom_up(rv, f)
#     668
#     669
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in <listcomp>(.0)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in <listcomp>(.0)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in <listcomp>(.0)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in <listcomp>(.0)
#    1145     if args is not None:
#    1146         if args:
# -> 1147             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
# -> 1150             rv = F(rv)
#    1151         elif atoms:
#    1152             rv = F(rv)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/fu.py in f(rv)
#     620         if first:
#     621             n, d = [expand_mul(i) for i in rv.as_numer_denom()]
# --> 622             newn = TR8(n, first=False)
#     623             newd = TR8(d, first=False)
#     624             if newn != n or newd != d:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/fu.py in TR8(rv, first)
#     665         return TR8(expand_mul(Mul(*args)))
#     666
# --> 667     return bottom_up(rv, f)
#     668
#     669
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1148             if args != rv.args:
#    1149                 rv = rv.func(*args)
# -> 1150             rv = F(rv)
#    1151         elif atoms:
#    1152             rv = F(rv)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/simplify/fu.py in f(rv)
#     630
#     631         args = {cos: [], sin: [], None: []}
# --> 632         for a in ordered(Mul.make_args(rv)):
#     633             if a.func in (cos, sin):
#     634                 args[a.func].append(a.args[0])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/core/compatibility.py in ordered(seq, keys, default, warn)
#     713                     raise ValueError(
#     714                         'not enough keys to break ties: %s' % u)
# --> 715         for v in d[k]:
#     716             yield v
#     717         d.pop(k)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/core/compatibility.py in ordered(seq, keys, default, warn)
#     713                     raise ValueError(
#     714                         'not enough keys to break ties: %s' % u)
# --> 715         for v in d[k]:
#     716             yield v
#     717         d.pop(k)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sympy/core/compatibility.py in ordered(seq, keys, default, warn)
#     700         d[None].extend(seq)
#     701
# --> 702     for k in sorted(d.keys()):
#     703         if len(d[k]) > 1:
#     704             if keys:
#
# KeyboardInterrupt:

# %%
#Create Composite force
CompositeForce = ef.CompositeForce(p,[wing_AeroForces,tip_AeroForces])
# Create the SYmbolic Model
sm = mf.SymbolicModel.FromElementsAndForces(p,[inner_wing_ele,tip_wing_ele],CompositeForce)

# %% [markdown]
# # Setup Numeric Model Parameters

# %%
tmax, dt = 5, 0.01
    
ts = np.arange(0, tmax+dt, dt)

constraints = [np.NaN]*p.qs*2
const_idx = np.isnan(constraints)

def objectiveDeriv(t,y):
    deriv = sm.deriv(t,y,p.GetNumericTuple(y,t))
    return tuple(np.where(const_idx,deriv,constraints))

# %% [markdown]
# ## create masses

# %%
y0 = [0]*p.qs*2
sm_mini = sm.subs(p,{p.alpha_1:p.alpha_1.value,p.alphadot_1:p.alphadot_1.value})
#sm_mini = sm_mini.subs(p,p.GetSubs(0,[0]*p.qs*2,ignore=[p.eta,p.EI,p.GJ,p.s_t,p.f_0,p.e_0,p.M_thetadot,p.V,p.alpha_1,p.alphadot_1,p.alpha_r]))

def objectiveDeriv(t,y):
    deriv = sm_mini.deriv(t,y,p.GetNumericTuple(y,t))
    return tuple(np.where(const_idx,deriv,constraints))

# %%
def objectiveDeriv(t,y):
    deriv = sm_mini.deriv(t,y,p.GetNumericTuple(y,t))
    return tuple(np.where(const_idx,deriv,constraints))

#set velocity and alpha_r funcs
def Vfunc(t,x):
    return 20

p.V.value = Vfunc

y0 = p.fp.value
y0 = [0]*p.qs*2
yData = solve_ivp(objectiveDeriv,(0,15),y0)
#yData = solve_ivp(objectiveDeriv,(0,tmax),yi[:,-1])

func_alpha = alpha_fwt.subs(p.GetSubs(0,y0))

# %%
yi = yData.y
t = yData.t

plt.style.use('seaborn-white')

fig, axes = plt.subplots(2,int(len(yi)/2),figsize=(15,5))

for i in range(int(len(yi)/2)):
    # pos plot
    axes[0][i].plot(t,yi[i*2])
    axes[0][i].set_ylabel('')
    axes[0][i].set_xlabel('t [s]')
    #axes[0][i].set(xlim=(0,0.1))
    
    # vel plot
    axes[1][i].plot(t,yi[i*2+1])
    axes[1][i].set_ylabel('')
    axes[1][i].set_xlabel('t [s]')
    #axes[1][i].set(xlim=(0,0.1))

# %% [markdown]
# ## Create the linearised EoM about some Stationary point

# %%
ignores = [p.EI,p.V,p.GJ,p.s_t,p.e_0,p.rho_t,p.m_1,p.alpha_r,p.ratio_fwt,p.Lambda]

# get the linearised sm
sm_lin = sm.subs(p,p.GetSubs(0,p.fp,ignore=ignores)).linearise(p)

# %%
# tweek model for FWT mass

# add a mass factor to FWT mass and sub it in
p.delta_f = mf.ModelSymbol(value = 1,string = 'delta_f')
sm_lin = sm_lin.subs(p,{p.m_1:p.rho_t*p.c.value*p.s_t*p.ratio_fwt*p.delta_f})

ignores = ignores + [p.delta_f]

# get eigen Matrices and turn into a function
K,M = sm_lin.eigenMatrices(p)
func = sym.lambdify((ignores + [p.fp]),(K,M))

f = (sm_mini.f-sm_mini.ExtForces.Q()).subs({i:0 for i in p.qd}).subs(p.GetSubs(0,[0]*p.qs*2,ignore=ignores))
func_obj = sym.lambdify((p.q,ignores),f)
func_jac_obj = sym.lambdify((p.q,ignores),f.jacobian(p.q))

# %%
p.alpha_r.value = 0 

#create dict of variations
vars_ls =[]
vars_ls.append((p.delta_f,np.array([0.5,1,1.5,2])))
#vars_ls.append((p.Lambda,np.deg2rad([10,17.5,25])))
#vars_ls.append((p.alpha_r,np.deg2rad([0,5,10])))
vars_ls.append((p.ratio_fwt,[0,0.1,0.2,0.3]))

vars_ls.append((p.V,np.linspace(0,150,151))) # ensure velocity last so that fixed points iterats up the velocity
#generate fixed points

#create an array of all possible permutations
perms = np.array(np.meshgrid(*[v for k,v in vars_ls ])).T.reshape(-1,len(vars_ls))

#put in pandas array
df = pd.DataFrame(data = perms, columns=[k.name for k,v in vars_ls])
df['q']=list
df = df.sort_values(by=[k.name for k,v in vars_ls]).reset_index()

# %%
## Find fixed point for each use case
pLast = [0]*p.qs
pLast[-1] = np.pi/2
for i in range(len(df)):
    
    #set param values
    for k,v in vars_ls:
        k.value = df[k.name].iloc[i]
    
    #set the initial guess (if v=0 set to FWT dropped doen else use previous result)
    if p.V.value == 0:
        q_guess = [0]*p.qs
        q_guess[-1] = np.pi/2
    else:
        q_guess = df.at[i-1,'q'][::2]
    values = tuple([i.value for i in ignores])
    qf = fsolve(lambda q,v: func_obj(q,values)[:,0],q_guess,fprime = func_jac_obj ,factor = 1,args=(values,))
    #print(f'{np.round(q_guess[-1],2)},{np.round(qf[-1],2)},{p.V.value}')
    #save result
    yf = [0]*p.qs*2  
    yf[::2] = qf
    df.at[i,'q'] = yf

# %%
#Calc freqs and dampings
flutdfv2 = pd.DataFrame() 
for i in range(0,len(df)):
    
    #set param values
    for k,v in vars_ls:
        k.value = df[k.name].iloc[i]

    q = df.at[i,'q']
    
    values = tuple([i.value for i in ignores])
    evals, evecs = eig(*func(*values,q))
    jac_dat = mf.ExtractEigenValueData(evals,evecs,sortby='Frequency')

    # populate test specific data
    for k,v in vars_ls:
        jac_dat[k.name] = k.value
        
    # populate fixed point data
    y = np.array(q)
    for i in range(len(y)):
        jac_dat[f'q_{i}'] =y[i]
    flutdfv2 = flutdfv2.append(jac_dat,sort=False)
        
flutdfv2 = flutdfv2.reset_index(drop=True)

# %%
data = flutdfv2.copy()
data = data[data['delta_f']==1]
#data = data[data['alpha_r']==np.deg2rad(0)]
#data = data[data['m_1']>40]
#data = data[data['m_1']<50]
data = data[data['V']<=140]
data['Damping [%]'] = data['Damping']*-100
data['Ratio FWT [%]'] = [str(i)+' %' for i in data['sigma']*100]
#print(data[['V','q_12']].head(50))
#data = flutdfv2
fig, axes = plt.subplots(3,1,figsize=(8,20))


sns.scatterplot(data=data,x='V',y='Frequency',hue='Ratio FWT [%]',ax=axes[0],edgecolor = 'none',s=15)
sns.scatterplot(data=data,x='V',y='Damping [%]',hue='Ratio FWT [%]',ax=axes[1],legend=False,edgecolor = 'none',s=15)
sns.scatterplot(data=data,x='V',y=f'q_{p.qs*2-2}',hue='Ratio FWT [%]',ax=axes[2],legend=False,edgecolor = 'none',s=15)

for i in [0,1,2]:
    #axes[i].set(xlim=(0,60))
    axes[i].grid(b=True, which='major', color='#999999', linestyle='--')
    axes[i].minorticks_on()
    axes[i].grid(b=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
    #axes[i].set(xlim=(0,60))
#axes[0].set(ylim=(0.5,3))
axes[0].set(ylim=(0,25))
axes[1].set(ylim=(-20,20))
# Out:
# [(-20, 20)]

# %%
data = flutdfv2.copy()
data = data[data['V']<=140]
data['Damping [%]'] = data['Damping']*-100
data['$\Lambda$ [deg]'] = [str(i)+' deg' for i in np.rad2deg(data['Lambda'])]
data['AoA [deg]'] = [str(i)+' deg' for i in np.rad2deg(data['alpha_r'])]
data['FWT Mass [%]'] = [str(i)+'%' for i in data['m_1']/data['m_1'].max()*200]
#print(data[['V','q_12']].head(50))
#data = flutdfv2
fig, axes = plt.subplots(3,1,figsize=(8,20))

huestr = 'AoA [deg]'
huestr = '$\Lambda$ [deg]'
#huestr = 'FWT Mass [%]'

#data = data[data['Lambda']==np.deg2rad(25)]
data = data[data['alpha_r']==np.deg2rad(00)]
data = data[data['m_1']>40]
data = data[data['m_1']<50]


sns.scatterplot(data=data,x='V',y='Frequency',hue=huestr,ax=axes[0],edgecolor = 'none',s=15)
sns.scatterplot(data=data,x='V',y='Damping [%]',hue=huestr,ax=axes[1],legend=False,edgecolor = 'none',s=15)
sns.scatterplot(data=data,x='V',y=f'q_{p.qs*2-2}',hue=huestr,ax=axes[2],legend=False,edgecolor = 'none',s=15)

for i in [0,1,2]:
    #axes[i].set(xlim=(0,60))
    axes[i].grid(b=True, which='major', color='#999999', linestyle='--')
    axes[i].minorticks_on()
    axes[i].grid(b=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
    #axes[i].set(xlim=(0,60))
#axes[0].set(ylim=(0.5,3))
axes[0].set(ylim=(0,10))
axes[1].set(ylim=(-20,20))
axes[2].set(ylim=(-1.6,1.6))
# Out:
# [(-1.6, 1.6)]

# %%
data['AoA [deg]']
# Out:
# 17333     0.0
# 17334     0.0
# 17335     0.0
# 17336     0.0
# 17337     0.0
#          ...
# 20681    10.0
# 20682    10.0
# 20683    10.0
# 20684    10.0
# 20685    10.0
# Name: AoA [deg], Length: 3184, dtype: object
