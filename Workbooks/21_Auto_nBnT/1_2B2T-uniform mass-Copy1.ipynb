# %%
import sympy as sym
import sympy.physics.mechanics as me
from sympy.abc import t as time
import pandas as pd
import seaborn as sns

import numpy as np
from scipy.integrate import odeint,LSODA,BDF,solve_ivp
from scipy.linalg import eig
from scipy.optimize import fsolve
import matplotlib.pyplot as plt

import moyra as ma
import moyra.elements as ele
import moyra.forces as ef

import sys, os
sys.path.insert(1, os.path.join(sys.path[0], '../..'))
import custom_plot_objects as cpo
import FwtModels as mf

me.mechanics_printing()

# %%
test_num = 6

b_modes = 3
t_modes = 2
fwt_modes = 1
modes = b_modes + t_modes + fwt_modes
main_panels = 20
fwt_panels = 15
tab_panels = 10
panels = main_panels + fwt_panels

p = ma.DynamicModelParameters(modes)

## Create some global parameters
p.b_modes = ma.ModelSymbol(value = b_modes,string = 'b_modes') # percentage of wing that is a FWT
p.t_modes = ma.ModelSymbol(value = t_modes,string = 't_modes') # percentage of wing that is a FWT

p.c = ma.ModelSymbol(value = 0.15,string = 'c') # chord of wing
p.s_i = ma.ModelSymbol(value = 1,string = 's_i') # total semi-span of wing
p.s_f = ma.ModelSymbol(value = 0.345,string = 's_f') # total semi-span of wingtip
p.s_t = ma.ModelSymbol(value = 0.1,string = 's_t') # total length of the tab
p.alpha_r = ma.ModelSymbol(value = np.deg2rad(3),string = 'alpha_r') # root AoA

## inner beam section
p.s_1 = ma.ModelSymbol(value = 0.8,string = 's_1') # total length of the tab
p.c_b = ma.ModelSymbol(value = 0.03,string = 'c_b') # chord of beam
p.rho_b = ma.ModelSymbol(value = 19.53,string = 'rho_b') # beam mass per unit area (kg/m^2)

## outer beam section
p.c_b2 = ma.ModelSymbol(value = 0.02,string = 'c_b2') # chord of beam
p.rho_b2 = ma.ModelSymbol(value = 19.53,string = 'rho_b2') # beam mass per unit area (kg/m^2)
p.EI = ma.ModelSymbol(value = 9.77e6,string = 'EI') # Bending stiffness for the wing
p.GJ = ma.ModelSymbol(value = 0.99e6,string = 'GJ') # Torsional Stiffness for the wing

## wing uniform mass
p.rho_w = ma.ModelSymbol(value = 19.53,string = 'rho_w') # wing mass per unit area (kg/m^2)
p.c_w = ma.ModelSymbol(value = 0.15,string = 'c_w') # chord over which to integrate wing mass
p.EI_2 = ma.ModelSymbol(value = 9.77e6,string = 'EI_2') # Bending stiffness for the wing
p.GJ_2 = ma.ModelSymbol(value = 0.99e6,string = 'GJ_2') # Torsional Stiffness for the wing


# Location of flexural axes fro beam
p.e_0 = ma.ModelSymbol(value = 0.08,string = 'e_0')
p.x_f0 = ma.ModelSymbol(value = 0.08,string = 'x_f')

# FWT mass element
p.m_f = ma.ModelSymbol(value = 0.3,string = 'm_f')
p.x_comf = ma.ModelSymbol(value = 0.3,string = 'x_comf')
p.y_comf = ma.ModelSymbol(value = 0.3,string = 'y_comf')
p.I_xxf = ma.ModelSymbol(value = 0.3,string = 'I_xxf') # inertia of FWT (uniform bar)
p.I_yyf = ma.ModelSymbol(value = 0.3,string = 'I_yyf') # inertia of FWT (uniform bar)

# FWT properties
p.Lambda = ma.ModelSymbol(value = np.deg2rad(10),string = 'Lambda') # Flare Angle
p.mu = ma.ModelSymbol(value = 0,string = 'mu')                 # dihedral angle at the end of the inner wing
p.mu_d = ma.ModelSymbol(value = 0,string = 'mu_d') # rate of change of dihedral angle at the tip of the inner wing

# Symbols to translate along inner wing and FWT
p.y_0 =ma.ModelSymbol(value = 0,string = 'y_0')        # inner wing y chord
p.x_0 = ma.ModelSymbol(value = 0,string = 'x_0')       # inner wing x chord
p.y_1 = ma.ModelSymbol(value = 0,string = 'y_1')       # FWT y chord
p.x_1 = ma.ModelSymbol(value = 0,string = 'x_1')       # FWT x chord

# Unsteady Aero Terms
p.k = ma.ModelSymbol(value = 0,string = 'k')    # reduced frequency
p.AR = ma.ModelSymbol(value = 0,string = 'AR')    # Aspect Ratio
p.M_thetadot = ma.ModelSymbol(value = -1.2,string = 'M_thetadot')    # Unsteady Torsional Term

## Aero Parameters
p.rho = ma.ModelSymbol(value = 1.225,string = 'rho')                 # density
p.V = ma.ModelSymbol(value = 10,string = 'V')                        # velocity
p.c_dmax = ma.ModelSymbol(value = 0.01,string = 'c_dmax')             # c_dmax
p.x_l = ma.ModelSymbol(value = 0.25,string = 'x_l')    # location of lift as percentage of the chord

# C_L curve terms
p.alpha_max = ma.ModelSymbol(value = np.deg2rad(15),string = 'alpha_max')# peak AoA
p.clip_factor = ma.ModelSymbol(value = 0.1,string = 'clip_factor')    # clipping factor for stall
p.stall_factor = ma.ModelSymbol(value = 0.1,string = 'stall_factor')    # clipping factor for stall
p.stall_rate = ma.ModelSymbol(value = np.deg2rad(0.5),string = 'stall_rate')    # clipping factor for stall
p.a_i = ma.ModelSymbol(value = 2*np.pi,string = 'a_i')               # C_L slope of main wing
p.a_0i = ma.ModelSymbol(value = 2*np.pi,string = 'a_0i')               # C_L slope of main wing
p.a = ma.ModelMatrix(value =[np.pi*2]*panels,length=panels, string='a') # local C_l

# gravity terms
p.g  = ma.ModelSymbol(value = 9.81,string = 'g')                     # gravity
p.g_v = ma.ModelMatrix(value =[0,0,-1],length=3,string='g_v')      # gravity unit vector


## FWT tab Wing Specific
p.beta_t = ma.ModelSymbol(value = 0,string = 'beta_t')               # tab
p.beta_m = ma.ModelSymbol(value = 0,string = 'beta_m')               # tab
p.beta_a = ma.ModelSymbol(value = 0,string = 'beta_a')               # tab

## FWT Aero Specific
p.alpha_1 = ma.ModelSymbol(value = 0,string = 'alpha_1')             # FWT alpha
p.alphadot_1 = ma.ModelSymbol(value = 0,string = 'alphadot_1')       # FWT alphadot

## Numeric Model Constants
p.fp = ma.ModelMatrix(value =[0]*p.qs*2,length=p.qs*2,string='fp') # The stationary point

# Factor to change the size of joint values
p.eta = ma.ModelMatrix(value = [1]*modes,length=modes,string='eta')

# %%
#get shape functions for main wing
z_0,tau_0 = ele.FlexiElement.ShapeFunctions_BN_TM(b_modes,t_modes,p.q[:-1],p.y_0,p.x_0,0,0,factor=p.eta,type='taylor')
# apply weighting function
#define wrefernce frames
# wing_root_frame = ma.HomogenousTransform().R_y(p.alpha_r)
wing_root_frame = ma.HomogenousTransform()

wing_frame = wing_root_frame.Translate(p.x_0,p.y_0,z_0)
wing_flexural_frame = wing_root_frame.Translate(0,p.y_0,z_0.subs({p.x_0:0}))

# fwt_root_frame = wing_frame.subs({p.x_0:p.x_f0,p.y_0:p.s_i}).R_x(p.q[-1]).simplify()
tip_twist = tau_0.subs({p.y_0:p.s_i})
fwt_root_frame = wing_flexural_frame.subs({p.y_0:p.s_i}).R_y(tip_twist).R_x(p.q[-1]).simplify()

fwt_frame = fwt_root_frame.Translate(p.x_1-p.x_f0,p.y_1,0)

x_aero = p.c*p.x_l - p.x_f0
y_aero = (p.y_1+x_aero*sym.tan(p.Lambda))*sym.cos(p.Lambda)
fwt_aero_frame =  wing_flexural_frame.subs({p.y_0:p.s_i}).R_x(p.q[-1]).Translate(x_aero,y_aero,0).simplify()

# %%
#Create Elemnts
M_wing = ele.MassMatrix(p.rho_w)
M_beam = ele.MassMatrix(p.rho_b)
M_beam2 = ele.MassMatrix(p.rho_b2)
M_fwt = ele.MassMatrix(p.m_f,I_xx = p.I_xxf,I_yy = p.I_yyf)

## inner beam element
beam_x_int = (p.x_0,-p.c_b/2,p.c_b/2)
beam_y_int = (p.y_0,0,p.s_1)
beam_mass_ele = ele.FlexiElement(wing_frame,M_beam,p.x_0,p.y_0,beam_x_int,beam_y_int,0,p.EI,p.GJ,gravityPot=True)

## outer beam element
beam2_x_int = (p.x_0,-p.c_b2/2,p.c_b2/2)
beam2_y_int = (p.y_0,p.s_1,p.s_i)
beam2_mass_ele = ele.FlexiElement(wing_frame,M_beam2,p.x_0,p.y_0,beam2_x_int,beam2_y_int,0,p.EI_2,p.GJ_2,gravityPot=True)

## wing mass element inner
wing_x_int = (p.x_0,-p.x_f0,p.c_w-p.x_f0)
wing_y_int = (p.y_0,0,p.s_i)
wing_mass_ele = ele.FlexiElement(wing_frame,M_wing,p.x_0,p.y_0,wing_x_int,wing_y_int,0,0,0,gravityPot=True)

## FWT mass element
x_com = (p.x_comf-p.x_f0)
y_com = (p.y_comf + x_com*sym.tan(p.Lambda))*sym.cos(p.Lambda)
fwt_ele = ele.RigidElement(fwt_root_frame,M_fwt,True,[x_com,y_com,0])

# %%
from sympy.abc import y
def ramp(x,corner,sharpness):
    return 1/sharpness*sym.ln(1+sym.exp(sharpness*(x+corner)))

def make_cl(x,stall_angle,stall_factor,c_l_0,sharpness):
    c_l = ramp(x,stall_angle,sharpness)
    c_l -= ramp(x,-stall_angle,sharpness)*stall_factor
    c_l += ramp(x,-(stall_angle+p.stall_rate),sharpness)*(stall_factor-1)
    c_l += ramp(-x,-(stall_angle),sharpness)*(stall_factor-1)
    c_l -= ramp(-x,-(stall_angle+p.stall_rate),sharpness)*(stall_factor-1)
    c_l -= stall_angle
    c_l *= c_l_0
    return c_l

c_l_func = lambda x: make_cl(x,p.alpha_max,p.stall_factor,p.a_i,p.clip_factor)
sym.simplify(make_cl(y,p.alpha_max,p.stall_factor,p.a_i,p.clip_factor))
# Out:
#     ⎛                                   ⎛     -clip_factor⋅(αₘₐₓ - y)⎞
# -aᵢ⋅⎝αₘₐₓ⋅clip_factor + stall_factor⋅log⎝1 + ℯ                       ⎠ + (stal
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                  ⎛⎛ clip_factor⋅(αₘₐₓ + stallᵣₐₜₑ + y)    ⎞  -clip_factor⋅(αₘₐ
# l_factor - 1)⋅log⎝⎝ℯ                                   + 1⎠⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ₓ + stallᵣₐₜₑ + y)⎞                         ⎛     -clip_factor⋅(αₘₐₓ + y)⎞
#                   ⎠ - (stall_factor - 1)⋅log⎝1 + ℯ                       ⎠ - (
# ──────────────────────────────────────────────────────────────────────────────
#      clip_factor
#
#                      ⎛     -clip_factor⋅(αₘₐₓ + stallᵣₐₜₑ - y)⎞      ⎛ clip_fa
# stall_factor - 1)⋅log⎝1 + ℯ                                   ⎠ - log⎝ℯ
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ctor⋅(αₘₐₓ + y)    ⎞⎞
#                 + 1⎠⎠
# ──────────────────────

# %%
# Main Wing Aero Forces 
wing_AeroForces = ef.AeroForce.PerUnitSpan(p,wing_flexural_frame,p.a_i,
                               alphadot = 0 if isinstance(tau_0,int) else tau_0.diff(me.dynamicsymbols._t),
                               M_thetadot = p.M_thetadot,
                               e = p.e_0,
                               w_g = 0,
                               root_alpha = p.alpha_r,
                                delta_alpha = tau_0,
                               alpha_zero = 0,
                               stall_angle = p.alpha_max,
                               c = p.c,
                                V = p.V,
                               c_d_max = p.c_dmax,
                               linear = True,
                                z_inverted=False,
                               unsteady=True,
                               c_l_func = lambda x: c_l_func(x))

# split Main Wing into segments
forces = []
for i in range(main_panels):
    seg_width = p.s_i/main_panels
    yi = seg_width/2 + i*seg_width
    forces.append(wing_AeroForces.subs({p.y_0:yi,p.a_i:p.a[i]})*seg_width)
    
Q = sym.Matrix([0]*p.qs)
for f in forces:
    Q += f.Q()
wing_AeroForces = ef.ExternalForce(Q)

# %%
# BodyJacobian = sym.simplify(ef.AeroForce._trigsimp(fwt_aero_frame.BodyJacobian(p.q)))
BodyJacobian = fwt_aero_frame.BodyJacobian(p.q)
C_L = p.a_i
alphadot = p.alphadot_1
M_thetadot = p.M_thetadot
e = 0
w_g = 0
root_alpha = p.alpha_1
delta_alpha = 0
alpha_zero = 0
stall_angle = p.alpha_max
c = p.c
V = p.V
c_d_max = p.c_dmax
linear = True
z_inverted=False
unsteady=True,
fwt_c_l_func = lambda x: c_l_func(x)+p.beta_t*p.beta_a*p.a_i
# fwt_c_l_func = lambda x: p.a_i*x+p.beta_t*p.beta_a*p.a_i
fwt_c_m_func = lambda x: p.beta_t*p.beta_m*p.a_i

dAlpha = ef.AeroForce.get_dAlpha(p,BodyJacobian,alphadot,alpha_zero, root_alpha, delta_alpha, w_g,V,c,z_inverted,unsteady)
F_n = ef.AeroForce.get_F_n(p,BodyJacobian,dAlpha,C_L,alpha_zero, stall_angle,c_d_max,V,c,linear,fwt_c_l_func)
M_w = ef.AeroForce.get_moment(p,BodyJacobian,dAlpha,F_n,C_L,alphadot,M_thetadot,e,V,c,0,fwt_c_m_func,unsteady)
F_a = ef.AeroForce.get_apparent_mass(p,BodyJacobian,C_L)


# component effecting bending
wrench_lift = sym.Matrix([0,0,-F_n,0,M_w,0]) if z_inverted else sym.Matrix([0,0,F_n,0,M_w,0])
Q_L = BodyJacobian.T*wrench_lift
fwt_AeroForces_perUnit = ef.AeroForce(Q_L,dAlpha)

# component effecting torsion
tau_s0 = tau_0.subs(p.y_0,p.s_i)
Transform = wing_frame.subs({p.y_0:p.s_i,p.x_0:p.x_f0}).R_y(tau_s0)
fwt_aeroTorque = ef.BodyForce(p,Transform,simplify=False,My = M_w*sym.cos(p.q[-1]))

# %%
# split FWT into segments
forces = []

# aero_mom_arm_offset = lambda x: yi#*sym.cos(p.Lambda)-p.c/(4*sym.cos(p.Lambda))
#first complete inner part without tab
seg_width = (p.s_f-p.s_t)/(fwt_panels-tab_panels)

for i in range(fwt_panels-tab_panels):
    yi = seg_width/2 + i*seg_width
    forces.append(fwt_AeroForces_perUnit.subs({p.y_1:yi,p.a_i:p.a[i+main_panels],p.beta_t:0})*seg_width)
    forces.append(fwt_aeroTorque.subs({p.y_1:yi,p.a_i:p.a[i+main_panels],p.beta_t:0})*seg_width)
    
# second complete part of wing with wingtip
ys = p.s_f-p.s_t
seg_width = p.s_t/tab_panels
for i in range(tab_panels):
    yi = ys + seg_width/2 + i*seg_width
    idx = main_panels + fwt_panels - tab_panels + i
    forces.append(fwt_AeroForces_perUnit.subs({p.y_1:yi,p.a_i:p.a[idx]})*seg_width)
    forces.append(fwt_aeroTorque.subs({p.y_1:yi,p.a_i:p.a[idx]})*seg_width)
    
# convert forces into matrix form
Q = sym.Matrix([0]*p.qs)
for f in forces:
    Q += f.Q()
fwt_AeroForces = ef.ExternalForce(Q)

# %%
#Create Composite force
CompositeForce = ef.CompositeForce([wing_AeroForces,fwt_AeroForces])
# Create the SYmbolic Model
sm = ma.SymbolicModel.FromElementsAndForces(p,[wing_mass_ele,beam_mass_ele,beam2_mass_ele,fwt_ele],CompositeForce)
# sm = ma.SymbolicModel.FromElementsAndForces(p,[wing_stiffness_ele,fwt_ele,mass_ele],CompositeForce)
# Out:
# 0
# 1
# 2
# 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-27fc82b16f1a> in <module>
#       2 CompositeForce = ef.CompositeForce([wing_AeroForces,fwt_AeroForces])
#       3 # Create the SYmbolic Model
# ----> 4 sm = ma.SymbolicModel.FromElementsAndForces(p,[wing_mass_ele,beam_mass_ele,beam2_mass_ele,fwt_ele],CompositeForce)
#       5 # sm = ma.SymbolicModel.FromElementsAndForces(p,[wing_stiffness_ele,fwt_ele,mass_ele],CompositeForce)
#
# c:\git\moyra\moyra\symbolic_model.py in FromElementsAndForces(cls, FwtParams, Elements, ExtForces)
#      64         for i,ele in enumerate(Elements):
#      65             print(i)
# ---> 66             T = ele.calc_ke(p)
#      67             U = ele.calc_pe(p)
#      68             D = ele.calc_rdf(p)
#
# c:\git\moyra\moyra\elements\rigid_element.py in calc_ke(self, p)
#      17
#      18     def calc_ke(self,p):
# ---> 19         M = self.M(p)
#      20
#      21         # calculate the K.E
#
# c:\git\moyra\moyra\elements\rigid_element.py in M(self, p)
#      28         Js = T.ManipJacobian(p.q)
#      29         Jb = T.InvAdjoint()*Js
# ---> 30         Jb = self._trigsimp(Jb) if self.simplify else Jb
#      31         #get M in world frame
#      32         #calculate the mass Matrix
#
# c:\git\moyra\moyra\elements\rigid_element.py in _trigsimp(self, expr)
#      34
#      35     def _trigsimp(self,expr):
# ---> 36         return sym.trigsimp(sym.powsimp(sym.cancel(sym.expand(expr))))
#      37
#      38
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\trigsimp.py in trigsimp(expr, **opts)
#     476     _eval_trigsimp = getattr(expr, '_eval_trigsimp', None)
#     477     if _eval_trigsimp is not None:
# --> 478         return _eval_trigsimp(**opts)
#     479
#     480     old = opts.pop('old', False)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\matrices\common.py in _eval_trigsimp(self, **opts)
#    2487     def _eval_trigsimp(self, **opts):
#    2488         from sympy.simplify import trigsimp
# -> 2489         return self.applyfunc(lambda x: trigsimp(x, **opts))
#    2490
#    2491     def upper_triangular(self, k=0):
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\matrices\common.py in applyfunc(self, f)
#    2024             raise TypeError("`f` must be callable.")
#    2025
# -> 2026         return self._eval_applyfunc(f)
#    2027
#    2028     def as_real_imag(self, deep=True, **hints):
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\matrices\common.py in _eval_applyfunc(self, f)
#    1964
#    1965     def _eval_applyfunc(self, f):
# -> 1966         out = self._new(self.rows, self.cols, [f(x) for x in self])
#    1967         return out
#    1968
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\matrices\common.py in <listcomp>(.0)
#    1964
#    1965     def _eval_applyfunc(self, f):
# -> 1966         out = self._new(self.rows, self.cols, [f(x) for x in self])
#    1967         return out
#    1968
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\matrices\common.py in <lambda>(x)
#    2487     def _eval_trigsimp(self, **opts):
#    2488         from sympy.simplify import trigsimp
# -> 2489         return self.applyfunc(lambda x: trigsimp(x, **opts))
#    2490
#    2491     def upper_triangular(self, k=0):
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\trigsimp.py in trigsimp(expr, **opts)
#     508                    }[method]
#     509
# --> 510     return trigsimpfunc(expr)
#     511
#     512
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\trigsimp.py in <lambda>(x)
#     501     trigsimpfunc = {
#     502         'fu': (lambda x: fu(x, **opts)),
# --> 503         'matching': (lambda x: futrig(x)),
#     504         'groebner': (lambda x: groebnersimp(x, **opts)),
#     505         'combined': (lambda x: futrig(groebnersimp(x,
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\trigsimp.py in futrig(e, hyper, **kwargs)
#    1100
#    1101     old = e
# -> 1102     e = bottom_up(e, _futrig)
#    1103
#    1104     if hyper and e.has(HyperbolicFunction):
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1193     if args is not None:
#    1194         if args:
# -> 1195             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1196             if args != rv.args:
#    1197                 rv = rv.func(*args)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\simplify.py in <listcomp>(.0)
#    1193     if args is not None:
#    1194         if args:
# -> 1195             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1196             if args != rv.args:
#    1197                 rv = rv.func(*args)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1193     if args is not None:
#    1194         if args:
# -> 1195             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1196             if args != rv.args:
#    1197                 rv = rv.func(*args)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\simplify.py in <listcomp>(.0)
#    1193     if args is not None:
#    1194         if args:
# -> 1195             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1196             if args != rv.args:
#    1197                 rv = rv.func(*args)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1196             if args != rv.args:
#    1197                 rv = rv.func(*args)
# -> 1198             rv = F(rv)
#    1199         elif atoms:
#    1200             rv = F(rv)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\trigsimp.py in _futrig(e)
#    1168             factor_terms, TR12(x), trigs)],  # expand tan of sum
#    1169         )]
# -> 1170     e = greedy(tree, objective=Lops)(e)
#    1171
#    1172     if coeff is not None:
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\strategies\core.py in minrule(expr)
#     109
#     110     def minrule(expr):
# --> 111         return min([rule(expr) for rule in rules], key=objective)
#     112     return minrule
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\strategies\core.py in <listcomp>(.0)
#     109
#     110     def minrule(expr):
# --> 111         return min([rule(expr) for rule in rules], key=objective)
#     112     return minrule
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\strategies\core.py in chain_rl(expr)
#      39     def chain_rl(expr):
#      40         for rule in rules:
# ---> 41             expr = rule(expr)
#      42         return expr
#      43     return chain_rl
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\trigsimp.py in <lambda>(x)
#    1145         TR10,  # sin-cos of sums -> sin-cos prod
#    1146         TR11, _TR11, TR6, # reduce double angles and rewrite cos pows
# -> 1147         lambda x: _eapply(factor, x, trigs),
#    1148         TR14,  # factored powers of identities
#    1149         [identity, lambda x: _eapply(_mexpand, x, trigs)],
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\trigsimp.py in _eapply(func, e, cond)
#    1193         return e
#    1194     if _is_Expr(e) or not e.args:
# -> 1195         return func(e)
#    1196     return e.func(*[
#    1197         _eapply(func, ei) if (cond is None or cond(ei)) else ei
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\polys\polytools.py in factor(f, deep, *gens, **args)
#    6388
#    6389     try:
# -> 6390         return _generic_factor(f, gens, args, method='factor')
#    6391     except PolynomialError as msg:
#    6392         if not f.is_commutative:
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\polys\polytools.py in _generic_factor(expr, gens, args, method)
#    6060     opt = options.build_options(gens, args)
#    6061     opt['fraction'] = fraction
# -> 6062     return _symbolic_factor(sympify(expr), opt, method)
#    6063
#    6064
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\polys\polytools.py in _symbolic_factor(expr, opt, method)
#    6000         if hasattr(expr,'_eval_factor'):
#    6001             return expr._eval_factor()
# -> 6002         coeff, factors = _symbolic_factor_list(together(expr, fraction=opt['fraction']), opt, method)
#    6003         return _keep_coeff(coeff, _factors_product(factors))
#    6004     elif hasattr(expr, 'args'):
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\polys\polytools.py in _symbolic_factor_list(expr, opt, method)
#    5965             func = getattr(poly, method + '_list')
#    5966
# -> 5967             _coeff, _factors = func()
#    5968             if _coeff is not S.One:
#    5969                 if exp.is_Integer:
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\polys\polytools.py in factor_list(f)
#    3334         if hasattr(f.rep, 'factor_list'):
#    3335             try:
# -> 3336                 coeff, factors = f.rep.factor_list()
#    3337             except DomainError:
#    3338                 return S.One, [(f, 1)]
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\polys\polyclasses.py in factor_list(f)
#     793     def factor_list(f):
#     794         """Returns a list of irreducible factors of ``f``. """
# --> 795         coeff, factors = dmp_factor_list(f.rep, f.lev, f.dom)
#     796         return coeff, [ (f.per(g), k) for g, k in factors ]
#     797
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\polys\factortools.py in dmp_factor_list(f, u, K0)
#    1409         if K.is_ZZ:
#    1410             levels, f, v = dmp_exclude(f, u, K)
# -> 1411             coeff, factors = dmp_zz_factor(f, v, K)
#    1412
#    1413             for i, (f, k) in enumerate(factors):
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\polys\factortools.py in dmp_zz_factor(f, u, K)
#    1146     if dmp_degree(g, u) > 0:
#    1147         g = dmp_sqf_part(g, u, K)
# -> 1148         H = dmp_zz_wang(g, u, K)
#    1149         factors = dmp_trial_division(f, H, u, K)
#    1150
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\polys\factortools.py in dmp_zz_wang(f, u, K, mod, seed)
#    1069     try:
#    1070         f, H, LC = dmp_zz_wang_lead_coeffs(f, T, cs, E, H, A, u, K)
# -> 1071         factors = dmp_zz_wang_hensel_lifting(f, H, LC, A, p, u, K)
#    1072     except ExtraneousFactors:  # pragma: no cover
#    1073         if query('EEZ_RESTART_IF_NEEDED'):
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\polys\factortools.py in dmp_zz_wang_hensel_lifting(f, H, LC, A, p, u, K)
#     933             if not dmp_zero_p(C, w - 1):
#     934                 C = dmp_quo_ground(C, K.factorial(k + 1), w - 1, K)
# --> 935                 T = dmp_zz_diophantine(G, C, I, d, p, w - 1, K)
#     936
#     937                 for i, (h, t) in enumerate(zip(H, T)):
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\polys\factortools.py in dmp_zz_diophantine(F, c, A, d, p, u, K)
#     878             if not dmp_zero_p(C, v):
#     879                 C = dmp_quo_ground(C, K.factorial(k + 1), v, K)
# --> 880                 T = dmp_zz_diophantine(G, C, A, d, p, v, K)
#     881
#     882                 for i, t in enumerate(T):
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\polys\factortools.py in dmp_zz_diophantine(F, c, A, d, p, u, K)
#     858         v = u - 1
#     859
# --> 860         S = dmp_zz_diophantine(G, C, A, d, p, v, K)
#     861         S = [ dmp_raise(s, 1, v, K) for s in S ]
#     862
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\polys\factortools.py in dmp_zz_diophantine(F, c, A, d, p, u, K)
#     878             if not dmp_zero_p(C, v):
#     879                 C = dmp_quo_ground(C, K.factorial(k + 1), v, K)
# --> 880                 T = dmp_zz_diophantine(G, C, A, d, p, v, K)
#     881
#     882                 for i, t in enumerate(T):
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\polys\factortools.py in dmp_zz_diophantine(F, c, A, d, p, u, K)
#     858         v = u - 1
#     859
# --> 860         S = dmp_zz_diophantine(G, C, A, d, p, v, K)
#     861         S = [ dmp_raise(s, 1, v, K) for s in S ]
#     862
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\polys\factortools.py in dmp_zz_diophantine(F, c, A, d, p, u, K)
#     858         v = u - 1
#     859
# --> 860         S = dmp_zz_diophantine(G, C, A, d, p, v, K)
#     861         S = [ dmp_raise(s, 1, v, K) for s in S ]
#     862
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\polys\factortools.py in dmp_zz_diophantine(F, c, A, d, p, u, K)
#     851
#     852         for f in F:
# --> 853             B.append(dmp_quo(e, f, u, K))
#     854             G.append(dmp_eval_in(f, a, n, u, K))
#     855
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\polys\densearith.py in dmp_quo(f, g, u, K)
#    1669
#    1670     """
# -> 1671     return dmp_div(f, g, u, K)[0]
#    1672
#    1673
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\polys\densearith.py in dmp_div(f, g, u, K)
#    1627         return dmp_ff_div(f, g, u, K)
#    1628     else:
# -> 1629         return dmp_rr_div(f, g, u, K)
#    1630
#    1631
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1395
#    1396         q = dmp_add_term(q, c, j, u, K)
# -> 1397         h = dmp_mul_term(g, c, j, u, K)
#    1398         r = dmp_sub(r, h, u, K)
#    1399
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\polys\densearith.py in dmp_mul_term(f, c, i, u, K)
#     182         return dmp_zero(u)
#     183     else:
# --> 184         return [ dmp_mul(cf, c, v, K) for cf in f ] + dmp_zeros(i, v, K)
#     185
#     186
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\polys\densearith.py in <listcomp>(.0)
#     182         return dmp_zero(u)
#     183     else:
# --> 184         return [ dmp_mul(cf, c, v, K) for cf in f ] + dmp_zeros(i, v, K)
#     185
#     186
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\polys\densearith.py in dmp_mul(f, g, u, K)
#     805     """
#     806     if not u:
# --> 807         return dup_mul(f, g, K)
#     808
#     809     if f == g:
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\polys\densearith.py in dup_mul(f, g, K)
#     765
#     766             for j in range(max(0, i - dg), min(df, i) + 1):
# --> 767                 coeff += f[j]*g[i - j]
#     768
#     769             h.append(coeff)
#
# KeyboardInterrupt:

# %%
fwt_ele.simplify = False
M = fwt_ele.M(p)
sym.simplify(M[4,3])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     453         try:
# --> 454             return self._assumptions[fact]
#     455         except KeyError:
#
# KeyError: 'extended_real'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     453         try:
# --> 454             return self._assumptions[fact]
#     455         except KeyError:
#
# KeyError: 'finite'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     453         try:
# --> 454             return self._assumptions[fact]
#     455         except KeyError:
#
# KeyError: 'extended_positive'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     453         try:
# --> 454             return self._assumptions[fact]
#     455         except KeyError:
#
# KeyError: 'zero'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     453         try:
# --> 454             return self._assumptions[fact]
#     455         except KeyError:
#
# KeyError: 'integer'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-5e5e704e2158> in <module>
#       1 fwt_ele.simplify = False
#       2 M = fwt_ele.M(p)
# ----> 3 sym.simplify(M[4,3])
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     694
#     695     if expr.has(TrigonometricFunction, HyperbolicFunction):
# --> 696         expr = trigsimp(expr, deep=True)
#     697
#     698     if expr.has(log):
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\trigsimp.py in trigsimp(expr, **opts)
#     508                    }[method]
#     509
# --> 510     return trigsimpfunc(expr)
#     511
#     512
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\trigsimp.py in <lambda>(x)
#     501     trigsimpfunc = {
#     502         'fu': (lambda x: fu(x, **opts)),
# --> 503         'matching': (lambda x: futrig(x)),
#     504         'groebner': (lambda x: groebnersimp(x, **opts)),
#     505         'combined': (lambda x: futrig(groebnersimp(x,
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\trigsimp.py in futrig(e, hyper, **kwargs)
#    1100
#    1101     old = e
# -> 1102     e = bottom_up(e, _futrig)
#    1103
#    1104     if hyper and e.has(HyperbolicFunction):
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1193     if args is not None:
#    1194         if args:
# -> 1195             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1196             if args != rv.args:
#    1197                 rv = rv.func(*args)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\simplify.py in <listcomp>(.0)
#    1193     if args is not None:
#    1194         if args:
# -> 1195             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1196             if args != rv.args:
#    1197                 rv = rv.func(*args)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1193     if args is not None:
#    1194         if args:
# -> 1195             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1196             if args != rv.args:
#    1197                 rv = rv.func(*args)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\simplify.py in <listcomp>(.0)
#    1193     if args is not None:
#    1194         if args:
# -> 1195             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1196             if args != rv.args:
#    1197                 rv = rv.func(*args)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1193     if args is not None:
#    1194         if args:
# -> 1195             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1196             if args != rv.args:
#    1197                 rv = rv.func(*args)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\simplify.py in <listcomp>(.0)
#    1193     if args is not None:
#    1194         if args:
# -> 1195             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1196             if args != rv.args:
#    1197                 rv = rv.func(*args)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1193     if args is not None:
#    1194         if args:
# -> 1195             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1196             if args != rv.args:
#    1197                 rv = rv.func(*args)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\simplify.py in <listcomp>(.0)
#    1193     if args is not None:
#    1194         if args:
# -> 1195             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1196             if args != rv.args:
#    1197                 rv = rv.func(*args)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1196             if args != rv.args:
#    1197                 rv = rv.func(*args)
# -> 1198             rv = F(rv)
#    1199         elif atoms:
#    1200             rv = F(rv)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\trigsimp.py in _futrig(e)
#    1168             factor_terms, TR12(x), trigs)],  # expand tan of sum
#    1169         )]
# -> 1170     e = greedy(tree, objective=Lops)(e)
#    1171
#    1172     if coeff is not None:
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\strategies\core.py in minrule(expr)
#     109
#     110     def minrule(expr):
# --> 111         return min([rule(expr) for rule in rules], key=objective)
#     112     return minrule
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\strategies\core.py in <listcomp>(.0)
#     109
#     110     def minrule(expr):
# --> 111         return min([rule(expr) for rule in rules], key=objective)
#     112     return minrule
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\strategies\core.py in chain_rl(expr)
#      39     def chain_rl(expr):
#      40         for rule in rules:
# ---> 41             expr = rule(expr)
#      42         return expr
#      43     return chain_rl
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\strategies\core.py in minrule(expr)
#     109
#     110     def minrule(expr):
# --> 111         return min([rule(expr) for rule in rules], key=objective)
#     112     return minrule
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\strategies\core.py in <listcomp>(.0)
#     109
#     110     def minrule(expr):
# --> 111         return min([rule(expr) for rule in rules], key=objective)
#     112     return minrule
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\fu.py in TR8(rv, first)
#     474         return TR8(expand_mul(Mul(*args)))
#     475
# --> 476     return bottom_up(rv, f)
#     477
#     478
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1196             if args != rv.args:
#    1197                 rv = rv.func(*args)
# -> 1198             rv = F(rv)
#    1199         elif atoms:
#    1200             rv = F(rv)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\fu.py in f(rv)
#     429         if first:
#     430             n, d = [expand_mul(i) for i in rv.as_numer_denom()]
# --> 431             newn = TR8(n, first=False)
#     432             newd = TR8(d, first=False)
#     433             if newn != n or newd != d:
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\fu.py in TR8(rv, first)
#     474         return TR8(expand_mul(Mul(*args)))
#     475
# --> 476     return bottom_up(rv, f)
#     477
#     478
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1193     if args is not None:
#    1194         if args:
# -> 1195             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1196             if args != rv.args:
#    1197                 rv = rv.func(*args)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\simplify.py in <listcomp>(.0)
#    1193     if args is not None:
#    1194         if args:
# -> 1195             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1196             if args != rv.args:
#    1197                 rv = rv.func(*args)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1196             if args != rv.args:
#    1197                 rv = rv.func(*args)
# -> 1198             rv = F(rv)
#    1199         elif atoms:
#    1200             rv = F(rv)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\simplify\fu.py in f(rv)
#     463             a1 = c.pop()
#     464             a2 = c.pop()
# --> 465             args.append((cos(a1 + a2) + cos(a1 - a2))/2)
#     466         if c:
#     467             args.append(cos(c.pop()))
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      70         def wrapper(*args, **kwargs):
#      71             try:
# ---> 72                 retval = cfunc(*args, **kwargs)
#      73             except TypeError:
#      74                 retval = func(*args, **kwargs)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\function.py in __new__(cls, *args, **options)
#     471
#     472         evaluate = options.get('evaluate', global_parameters.evaluate)
# --> 473         result = super().__new__(cls, *args, **options)
#     474         if evaluate and isinstance(result, cls) and result.args:
#     475             pr2 = min(cls._should_evalf(a) for a in result.args)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      70         def wrapper(*args, **kwargs):
#      71             try:
# ---> 72                 retval = cfunc(*args, **kwargs)
#      73             except TypeError:
#      74                 retval = func(*args, **kwargs)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\function.py in __new__(cls, *args, **options)
#     283
#     284         if evaluate:
# --> 285             evaluated = cls.eval(*args)
#     286             if evaluated is not None:
#     287                 return evaluated
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\functions\elementary\trigonometric.py in eval(cls, arg)
#     585             return arg._eval_func(cls)
#     586
# --> 587         if arg.is_extended_real and arg.is_finite is False:
#     588             return AccumBounds(-1, 1)
#     589
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     456             if self._assumptions is self.default_assumptions:
#     457                 self._assumptions = self.default_assumptions.copy()
# --> 458             return _ask(fact, self)
#     459
#     460     getit.func_name = as_property(fact)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     499         pass
#     500     else:
# --> 501         a = evaluate(obj)
#     502         if a is not None:
#     503             assumptions.deduce_all_facts(((fact, a),))
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\expr.py in _eval_is_negative(self)
#     854
#     855     def _eval_is_negative(self):
# --> 856         finite = self.is_finite
#     857         if finite is False:
#     858             return False
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     456             if self._assumptions is self.default_assumptions:
#     457                 self._assumptions = self.default_assumptions.copy()
# --> 458             return _ask(fact, self)
#     459
#     460     getit.func_name = as_property(fact)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     499         pass
#     500     else:
# --> 501         a = evaluate(obj)
#     502         if a is not None:
#     503             assumptions.deduce_all_facts(((fact, a),))
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\expr.py in _eval_is_positive(self)
#     847         if finite is False:
#     848             return False
# --> 849         extended_positive = self.is_extended_positive
#     850         if finite is True:
#     851             return extended_positive
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     456             if self._assumptions is self.default_assumptions:
#     457                 self._assumptions = self.default_assumptions.copy()
# --> 458             return _ask(fact, self)
#     459
#     460     getit.func_name = as_property(fact)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     499         pass
#     500     else:
# --> 501         a = evaluate(obj)
#     502         if a is not None:
#     503             assumptions.deduce_all_facts(((fact, a),))
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\add.py in _eval_is_extended_positive(self)
#     750         pos = nonneg = nonpos = unknown_sign = False
#     751         saw_INF = set()
# --> 752         args = [a for a in self.args if not a.is_zero]
#     753         if not args:
#     754             return False
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\add.py in <listcomp>(.0)
#     750         pos = nonneg = nonpos = unknown_sign = False
#     751         saw_INF = set()
# --> 752         args = [a for a in self.args if not a.is_zero]
#     753         if not args:
#     754             return False
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     456             if self._assumptions is self.default_assumptions:
#     457                 self._assumptions = self.default_assumptions.copy()
# --> 458             return _ask(fact, self)
#     459
#     460     getit.func_name = as_property(fact)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     499         pass
#     500     else:
# --> 501         a = evaluate(obj)
#     502         if a is not None:
#     503             assumptions.deduce_all_facts(((fact, a),))
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\mul.py in _eval_is_even(self)
#    1570
#    1571     def _eval_is_even(self):
# -> 1572         is_integer = self.is_integer
#    1573
#    1574         if is_integer:
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     456             if self._assumptions is self.default_assumptions:
#     457                 self._assumptions = self.default_assumptions.copy()
# --> 458             return _ask(fact, self)
#     459
#     460     getit.func_name = as_property(fact)
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     511             continue
#     512         if pk in handler_map:
# --> 513             _ask(pk, obj)
#     514
#     515             # we might have found the value of fact
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     501         a = evaluate(obj)
#     502         if a is not None:
# --> 503             assumptions.deduce_all_facts(((fact, a),))
#     504             return a
#     505
#
# ~\AppData\Local\Continuum\anaconda3\envs\fwtmodels\lib\site-packages\sympy\core\facts.py in deduce_all_facts(self, facts)
#     532                 bcond, bimpl = beta_rules[bidx]
#     533                 if all(self.get(k) is v for k, v in bcond):
# --> 534                     facts.append(bimpl)
#
# KeyboardInterrupt:

# %%
wing_mass_ele.Transform.E

# %%
t = me.dynamicsymbols._t
# expression for dihedral angle at the end of the inner wing
d_z_s0 = z_0.diff(p.y_0).subs({p.y_0:p.s_i,p.x_0:0})
d_d_z_s0 = d_z_s0.diff(t)

# dummy function for dihedral angle at the end of the inner wing
dummy = sym.Function('d')(t)

# get expression for AoA on the FWT with fold angle
fwt_aoa = mf.GetAoA(p.alpha_r+tau_0.subs({p.y_0:p.s_i}),0,p.Lambda,p.q[-1]-dummy,dummy)
d_fwt_aoa = fwt_aoa.diff(t)
# sub in place holder term for the dihedral angle and derivative with time 
d_fwt_aoa = d_fwt_aoa.subs({dummy.diff(t):p.mu_d,dummy:p.mu})
fwt_aoa = fwt_aoa.subs({dummy:p.mu})

# %%
# sub in expersions for AoA
sm = sm.subs({p.alpha_1:fwt_aoa,p.alphadot_1:d_fwt_aoa})

# %%
# export to matlab
sm.to_matlab_file(p,'C:/Git/scitech2022_post_flutter/+model/')

# %%
sm_lin = sm.subs({sym.sin(p.q[-1]):p.q[-1],sym.cos(p.q[-1]):1})

# %%
sm_lin.to_matlab_file(p,'C:/Git/scitech2022_post_flutter/+model_lin/')

# %%
# make files in matlab to get teh diherdral angle at the end of the innenr wing
file_dir ='C:/Git/scitech2022_post_flutter/+model/'
func_name = 'd_z_s0'
with open(file_dir+f"{func_name}.m",'w') as file:
    file.write(sm._gen_octave(d_z_s0,p,func_name))
    
func_name = 'd_d_z_s0'
with open(file_dir+f"{func_name}.m",'w') as file:
    file.write(sm._gen_octave(d_d_z_s0,p,func_name))

# %%
# make function to plot wings in matlab
main_wing_surf = wing_frame.Transform_point([0,0,0])
fwt_surf = fwt_frame.Transform_point([0,0,0])

func_name = 'main_wing_surf'
with open(file_dir+f"{func_name}.m",'w') as file:
    file.write(sm._gen_octave(main_wing_surf,p,func_name))
    
func_name = 'fwt_surf'
with open(file_dir+f"{func_name}.m",'w') as file:
    file.write(sm._gen_octave(fwt_surf,p,func_name))

# %%
from time import time, ctime
def gen_octave(expr,func_name):  
    symbols = sorted([s.name for s in expr.free_symbols], key=lambda L: (L.lower(), L))
    print(symbols)
    # split expr into groups
    replacments, exprs = sym.cse(expr,symbols=(sym.Symbol(f'rep_{i}')for i in range(10000)))
    if isinstance(expr,tuple):
        expr = tuple(exprs)
    elif isinstance(expr,list):
        expr = exprs
    else:
        expr = exprs[0]      

    group_string = '%% create common groups\n\t'
    for variable, expression in replacments:
        group_string +=f'{variable} = {sym.printing.octave.octave_code(expression)};\n\t'

    # convert to octave string and covert states to vector form
    out = '%% create output \n\tout = ' + sym.printing.octave.octave_code(expr)

    # make the file pretty...
    out = out.replace(',',',...\n\t\t').replace(';',';...\n\t\t')

    file_sig = f'%{func_name.upper()} Auto-generated function from moyra\n\t'
    file_sig += f'%\n\t'
    file_sig += f'%\tCreated at : {ctime(time())} \n\t'
    file_sig += f'%\tCreated with : moyra https://pypi.org/project/moyra/\n\t'
    file_sig += f'%\n\t'

    # wrap output in octave function signature
    signature = f'function out = {func_name}('
    for s in symbols:
        signature +=f'{s},'
    signature = signature[:-1]+')\n\t'
    octave_string = signature + file_sig  + group_string + out + ';\nend'
    return octave_string

# %%
## functions to get geometric AoA on Wingtip
file_dir ='C:/Git/scitech2022_post_flutter/+model/'
func_name = 'fwt_aoa'
with open(file_dir+f"{func_name}.m",'w') as file:
    file.write(gen_octave(fwt_aoa,func_name))
func_name = 'd_fwt_aoa'
with open(file_dir+f"{func_name}.m",'w') as file:
    file.write(gen_octave(d_fwt_aoa,func_name))

# %%
## functions to get C_l curve
func_name = 'C_l'
with open(file_dir+f"{func_name}.m",'w') as file:
    file.write(gen_octave(c_l_func(p.alpha_1),func_name))

# %%
## functions to get interesting outputs
hinge_z = z_0.subs({p.y_0:p.s_i,p.x_0:0})
hinge_twist = tau_0.subs({p.y_0:p.s_i,p.x_0:0})
hinge_dihedral = d_z_s0
fold_angle = p.q[-1] - hinge_dihedral
local_aoa_root = dAlpha.subs({p.alpha_1:fwt_aoa,p.y_1:0})
local_aoa_mid = dAlpha.subs({p.alpha_1:fwt_aoa,p.y_1:p.s_f/2})
local_aoa_tip = dAlpha.subs({p.alpha_1:fwt_aoa,p.y_1:p.s_f})

# %%
file_dir ='C:/Git/scitech2022_post_flutter/+model/'
func_names = ('hinge_z','hinge_twist','hinge_dihedral','fold_angle','local_aoa_root','local_aoa_mid','local_aoa_tip')
funcs = (hinge_z,hinge_twist,hinge_dihedral,fold_angle,local_aoa_root,local_aoa_mid,local_aoa_tip)
for fun,nam in zip(funcs,func_names):
    with open(file_dir+f"{nam}.m",'w') as file:
        file.write(sm._gen_octave(fun,p,nam))

# %%
import moyra.printing as moyp
test = sm._gen_octave(sm.f[0],p,'test')
test.find('Deriv')
